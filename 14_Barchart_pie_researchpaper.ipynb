# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams.update({'font.size': 8})

# %%
###dataset1
# Bring some raw data.
sentiment = [-1, -0.28, -0.25, -0.19, -0.03, 0.01, 0.09,
0.09, 0.13, 0.13, 0.13, 0.21, 0.28, 0.39, 0.42,
0.47, 0.56, 1]

freq_series = pd.Series(sentiment)

y_labels = ['work life balance', 'work atmosphere', 'equal rights',
'cohesion among colleagues', 'bad companies', 'vacation',
'work hours', 'circumstances at work - overtime', 'treatment of colleagues',
'job pressure', 'flexible work hours', 'work from home', 'communication in the organization',
'work atmosphere - interesting tasks', 'age diversity', 'treatment of leader',
'work atmosphere for new colleagues', 'good management']
#define colors
colors = [(200/255,200/255,200/255) for i in range(len(y_labels))]
colors[len(colors)-1] = (122/255,195/255,106/255)
colors[len(colors)-2] = (122/255,195/255,106/255)
colors[0] = (241/255,90/255,96/255)
colors[1] = (241/255,90/255,96/255)


# Plot the figure.
#plt.figure(figsize=(12, 8))
fig = plt.figure(figsize=(18/2.54,10.45/2.54)) #dt2
ax = fig.add_axes([0.38,0.1,0.61,0.89])
#left = 0.05
#bottom = 0.05
#width = 0.9
#height = 0.9

#ax = freq_series.plot(kind='barh', color = colors)
ax.barh(y_labels, sentiment, color = colors, height = 0.5)
#ax.set_title('Topic Sentiment Dataset1')
ax.set_xlabel('sentiment')
ax.set_ylabel('Topic terms')
#ax.set_yticklabels(y_labels)
ax.set_xlim(-1.2, 1.2) # expand xlim to make labels easier to read

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:.2f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.


plt.savefig("topicsent_BAR_dataset1.png")
plt.show()

# %%
###Dataset2

# Bring some raw data.
sentiment = [-1,
-0.440434793,
-0.337742705,
-0.020867005,
0.053067472,
0.089137945,
0.101232467,
0.112031285,
0.177681302,
0.182576964,
0.204081752,
0.210034003,
0.210791624,
0.216727314,
0.322702302,
0.34027275,
0.435305074,
0.50850881,
0.582385983,
1
]
freq_series = pd.Series(sentiment)

y_labels = ['work life balance', 'overtime job pressure', 'female leaders', 'bad salary', 'cultural diversity',
'fun environment', 'great education', 'women empowerment', 'communication in the organisation',
'cohesion among new colleagues', 'satisfaction with work and colleagues', 'gender diversity',
'relationships with colleagues and bosses', 'tasks at work', 'cohesion among colleagues',
'young team', 'appreciation of experience', 'work from home', 'work hours', 'age diversity']
#define colors
colors = [(200/255,200/255,200/255) for i in range(len(y_labels))]
colors[-1] = (122/255,195/255,106/255)
colors[-2] = (122/255,195/255,106/255)
colors[0] = (241/255,90/255,96/255)
colors[1] = (241/255,90/255,96/255)

# Plot the figure.

# Plot the figure.
#plt.figure(figsize=(12, 8))
fig = plt.figure(figsize=(18/2.54,10.45/2.54)) #dt2
ax = fig.add_axes([0.38,0.1,0.61,0.89])
#left = 0.05
#bottom = 0.05
#width = 0.9
#height = 0.9

#ax = freq_series.plot(kind='barh', color = colors)
ax.barh(y_labels, sentiment, color = colors, height = 0.5)
#ax.set_title('Topic Sentiment Dataset1')
ax.set_xlabel('sentiment')
ax.set_ylabel('Topic terms')
#ax.set_yticklabels(y_labels)
ax.set_xlim(-1.3, 1.3) # expand xlim to make labels easier to read

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:.2f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.


plt.savefig("topicsent_BAR_dataset2.png")
plt.show()

# %%
from matplotlib import pyplot as plt

print("Enter Pie")
explode = (0.1, 0.1, 0.1)  # explode 1st slice #remove this for other data
plt.style.use("fivethirtyeight")
fig = plt.figure(figsize=(9/2.54, 6.5/2.54), facecolor='white')

plt.rcParams.update({'font.size': 8})
ax = fig.add_axes([0.15,0.03,0.65,0.92])
#dftopicXSentiment[3].value_counts()
#print(dftopicXSentiment[3].value_counts())
labels2 =['Positive\nSentiment', 'Negative\nSentiment','Neutral\nSentiment']  #remove this for other data
colors =['#7ac36a', '#f15a5f', '#c8c8c8']
ax.pie((69.57, 17.39, 13.04), explode=explode,
        labels = labels2, autopct='%.2f', wedgeprops={'edgecolor': 'black'},
        colors =colors, shadow=True, startangle=90)
fig.set_facecolor('white')
ax.patch.set_facecolor('white')
plt.title("")

plt.grid()
#plt.tight_layout()

#plt.savefig('113759_pie.png')

plt.savefig('PIE_DATASET2_NoHeader_pie_LIGHTGREY.jpg')
plt.show()
# Out:
# Enter Pie
